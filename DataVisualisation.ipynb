# %%
# !pip install pandas -U
# !pip install matplotlib -U
# !pip install seaborn -U
# Out:
# ...
#                                               0.0/10.7 MB ? eta -:--:--
#                                               0.2/10.7 MB 6.9 MB/s eta 0:00:02
#      ---                                      0.9/10.7 MB 11.6 MB/s eta 0:00:01
#      -----                                    1.5/10.7 MB 12.1 MB/s eta 0:00:01
#      --------                                 2.2/10.7 MB 12.6 MB/s eta 0:00:01
#      ----------                               2.8/10.7 MB 12.8 MB/s eta 0:00:01
#      -----------                              3.1/10.7 MB 12.4 MB/s eta 0:00:01
#      -----------                              3.1/10.7 MB 12.4 MB/s eta 0:00:01
#      ------------                             3.3/10.7 MB 9.3 MB/s eta 0:00:01
#      ----------------                         4.4/10.7 MB 11.3 MB/s eta 0:00:01
#      ----------------------                   6.0/10.7 MB 13.1 MB/s eta 0:00:01
#      ------------------------                 6.6/10.7 MB 13.1 MB/s eta 0:00:01
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !python --version
# Out:
# Python 3.9.13

# %%
import matplotlib
matplotlib.__version__
# Out:
# '3.7.1'

# %%
sns.__version__
# Out:
# '0.12.2'

# %%
cd
# Out:
# C:\Users\Maks

# %%
cd Documents
# Out:
# C:\Users\Maks\Documents

# %%
cd C:\Users\Maks\Documents\Adult\Python Projects\Finance Tracker
# Out:
# C:\Users\Maks\Documents\Adult\Python Projects\Finance Tracker

# %%
finance_data = pd.read.csv('data/Finances.csv')

finance_data.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 finance_data = pd.read.csv('data/Finances.csv')
#       3 finance_data.head()
#
# AttributeError: module 'pandas' has no attribute 'read'

# %%
finance_data = pd.read_csv('data/Finances.csv')

finance_data.head()
# Out:
#          Date                                        Description  Credit
# 0  2023-01-31  teampay - sports - visa purchase - receipt 163...     NaN  \
# 1  2023-01-30  everyday round up - everyday round up - receip...     NaN
# 2  2023-01-29  internal transfer - internal transfer - receip...     NaN
# 3  2023-01-29   e zak repayment - osko payment - receipt 853750   1000.0
# 4  2023-01-29  alexander guerrieri tough time never ... - osk...    20.0
#
#     Debit  Balance        Type
# 0  -23.32   189.58  Recreation
# 1   -1.68   212.90    Internal
# 2 -850.00   214.58    Internal
# 3     NaN  1064.58       Other
# 4     NaN    64.58       Other

# %%
finance_data.describe().T
# Out:
#           count        mean          std      min       25%      50%     75%
# Credit    169.0  534.763018  1149.805895     0.23   16.9000   50.000  267.31  \
# Debit     832.0 -108.395877   363.711423 -5000.00  -43.8125  -14.485   -3.98
# Balance  1002.0  901.167385  1055.167018     0.00  249.5925  598.945  959.76
#
#              max
# Credit   5014.55
# Debit      -0.01
# Balance  6342.15

# %%
sns.displot(data = finance_data, x = 'Date', aspect = 45)

# %%
f, ax = plt.subplots(figsize= (12,6))

sns.histplot(data = finance_data, x = 'Type')
# Out:
# <Axes: xlabel='Type', ylabel='Count'>

# %%
sns.displot(data=finance_data, x = 'Type', kde = True, aspect = 2)

# %%
sns.displot(data=finance_data, x = 'Type', kde = True, aspect = 2, shrink = 0.5)

# %%
sns.displot(data=finance_data, x = 'Type', kde = True, aspect = 2, rug = True)

# %%
f, ax = plt.subplots(figsize = (12,6))
sns.histplot(data = finance_data, x = 'Type', kde = True)

sns.rugplot(data = finance_data, x='Type')
# Out:
# <Axes: xlabel='Type', ylabel='Count'>

# %%
f, ax = plt.subplots(figsize = (12,6))
sns.kdeplot(data = finance_data, x = 'Balance', bw_adjust = 0.05, label = 'bw: 0.05')
# Out:
# <Axes: xlabel='Balance', ylabel='Density'>
